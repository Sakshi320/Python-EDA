# %% [markdown]
# #Exploratory data analysis on this dataset:

# %% [markdown]
# # Read Town-level Econ Data for MA
# * https://en.wikipedia.org/wiki/List_of_Massachusetts_locations_by_per_capita_income

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Massachusetts_locations_by_per_capita_income')[2]
df
# Out:
#      Rank  Municipality  Type     County Per capitaincome  \
# 0       1        Weston  Town  Middlesex         $105,217
# 1       2         Dover  Town    Norfolk          $89,476
# 2       3      Sherborn  Town  Middlesex          $82,550
# 3       4     Brookline  Town    Norfolk          $77,585
# 4       5        Newton  City  Middlesex          $73,420
# ..    ...           ...   ...        ...              ...
# 292   296       Amherst  Town  Hampshire          $19,796
# 293   297   Springfield  City    Hampden          $18,133
# 294   298      Lawrence  City      Essex          $16,987
# 295   299        Pelham  Town  Hampshire          $50,637
# 296   300  West Newbury  Town      Essex          $35,323
#
#     Medianhouseholdincome Medianfamilyincome  Population  Number ofhouseholds
# 0                $256,300          $250,000+       11261                10769
# 1                $187,829           $193,750        6279                 5891
# ...

# %%
# 8/30/2022
# edit: DW switched #Q1 and #Q2 so that it's easier to solve the assignment 
# and added some code hints for students

# %% [markdown]
# # Read this... then performed string substition (for $ , + and any other special characters) and convert `Per capitaincome`,	`Medianhouseholdincome`,	and `Medianfamilyincome` to numeric
# * https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html
# * https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
# * https://www.skytowner.com/explore/removing_comma_from_column_values_in_pandas_dataframe

# %%
# ignore the warning! it's just a warning for a future dependency
#Converting Per Capitaincome to numeric-
df['Per capitaincome'] = df['Per capitaincome'].str.replace('$', '')
df['Per capitaincome'] = df['Per capitaincome'].str.replace(',', '')
df['Per capitaincome'] = pd.to_numeric(df['Per capitaincome'], errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# ignore the warning! it's just a warning for a future dependency
#Converting Medianhouseholdincome to numeric-
df['Medianhouseholdincome'] = df['Medianhouseholdincome'].str.replace('$', '')
df['Medianhouseholdincome'] = df['Medianhouseholdincome'].str.replace(',', '')
df['Medianhouseholdincome'] = pd.to_numeric(df['Medianhouseholdincome'], errors='coerce')

#Converting Medianfamilyincome to numeric-
df['Medianfamilyincome'] = df['Medianfamilyincome'].str.replace('$', '')
df['Medianfamilyincome'] = df['Medianfamilyincome'].str.replace(',', '')
df['Medianfamilyincome'] = df['Medianfamilyincome'].str.replace('+', '')
df['Medianfamilyincome'] = pd.to_numeric(df['Medianfamilyincome'], errors='coerce')

df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %% [markdown]
# #  Counties have a `df['Per capitaincome']` greater than or equal to...
# * 30K
# * 65K

# %%
x = df[df['Per capitaincome']>=30000]
print("Countries having per capita income greater than or equal to 30K is=", len(x))
# Out:
# Countries having per capita income greater than or equal to 30K is= 229

# %%
x = df[df['Per capitaincome']>=65000]
print("Countries having per capita income greater than or equal to 65K is=", len(x))
# Out:
# Countries having per capita income greater than or equal to 65K is= 13

# %% [markdown]
# `.value_counts()` on the `df['type']` column.
# Describe what you see.

# %%
df['Type'].value_counts()
# Out:
# Town     249
# City      47
# Essex      1
# Name: Type, dtype: int64

# %% [markdown]
# After running the above code, I can count the number of rows for each unique value i.e., town, city and Essex.
# Also the data type is being showed as integer.

# %% [markdown]
# # A five number summary of the population column for each county.

# %%
df.groupby(["County"])['Population'].describe()

# groupby function will group all the county and describe function will summarize values in population column
# Out:
#             count           mean            std      min       25%      50%  \
# County
# Barnstable   11.0   18013.909091   12052.579811   2964.0  11004.50  14168.0
# Berkshire    26.0    4874.076923    8684.712817    478.0    923.25   1929.0
# Bristol      20.0   27631.650000   25392.661736   6452.0  12982.50  17096.5
# Dukes         5.0    3234.800000    2011.024913     75.0   2628.00   3995.0
# Essex        28.0   25653.535714   22990.163126   4500.0   8133.25  15969.5
# Franklin     24.0    2813.791667    3794.029589    117.0    906.00   1688.5
# Hampden      20.0   21647.100000   34945.270592    905.0   1792.00   9089.5
# Hampshire    17.0    7981.705882   10905.436974    464.0   1162.00   2655.0
# Middlesex    50.0   27675.640000   23039.356677   3114.0  10694.75  22077.0
# Nantucket     1.0   14255.000000            NaN  14255.0  14255.00  14255.0
# Norfolk      22.0   25387.409091   20662.828693   4400.0  11455.00  20692.5
# ...

# %% [markdown]
# # Histogram of the number of households column.

# %%
# Histogram for number of households column

plt.hist(df['Number ofhouseholds'],color="red")
plt.title('Number of households histogram')          #adding the title to the plot
plt.xlabel('Number of households')     # X label 
plt.ylabel('Count of households')      # Y label
plt.show()

# %%
plt.boxplot(df['Number ofhouseholds'])
plt.show()

# %% [markdown]
# I found Histogram would be a nice way of summarizing the data.
# Since the mean, median, etc values can be easily recognized from histogram compared to box plot

# %% [markdown]
# ##How many towns start with the letter 'W'

# %%
#Applying equal to condition to check for towns and startwith function to check the municipality starting with letter 'W'.
x1 = df[(df['Type']=='Town') & (df['Municipality'].str.startswith("W"))].value_counts() 
len(x1) #Calculating the length of the total value coming out from previous code.

#To check the work - 
#I have manually filtered out data in excel to cross check the number of towns starting with letter 'W' and got the same result as 36.
# Out:
# 36

# %% [markdown]
# # Scatterplot of `Population` vs. `Number ofhouseholds`

# %%
## scatter plot using library of matplotlib
df.plot.scatter(x='Population', y='Number ofhouseholds', color='blue')           
plt.xlabel("Population")  #Xlabel                                                          
plt.ylabel("Number Of Households") #Ylabel                                                
plt.title("Population vs. Number of Households") #Title for the scatter plot                             
plt.show()

# %% [markdown]
# # County has the highest average df['Rank']? The lowest `df['Rank]'

# %%
print("Lowest rank of County is:",df.groupby(["County"]).mean()['Rank'].sort_values().head(1))
#sorted the values from low to high then displayed first/lowest value with head

print("Highest rank of County is:",df.groupby(["County"]).mean()['Rank'].sort_values().tail(1))
#sorted the values from low to high then displayed last/highest irst value with tail
# Out:
# Lowest rank of County is: County
# Nantucket    16.0
# Name: Rank, dtype: float64
# Highest rank of County is: County
# Suffolk    211.5
# Name: Rank, dtype: float64

# %% [markdown]
# # Recreating the output from `df['Population'].describe()` using numpy.

# %%
# Recreating the output from describe using numpy-
# df['Population'].describe()
print("Mean of the population is:",np.mean(df['Population'])) #using mean function
print("Count of the population is:",np.size(df['Population'])) #using size function
print("Minimum of the population is:",np.min(df['Population'])) #using min function
print("Maximum of the population is:",np.max(df['Population'])) #using max function
print("Standard Deviation of the population is:",np.std(df['Population'])) #using std function
# Out:
# Mean of the population is: 20370.80808080808
# Count of the population is: 297
# Minimum of the population is: 75
# Maximum of the population is: 629182
# Standard Deviation of the population is: 42145.99568575452
